# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import keras

plt.style.use('seaborn')
sns.set(font_scale=2.5)

import missingno as msno

import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
os.listdir('.')
# Out:
# ['.DS_Store', 'apartment.ipynb', '.ipynb_checkpoints', 'Apartment.csv']

# %%
# 공공데이터 csv 에러 또는 한글 깨짐 해결법
# https://teddylee777.github.io/pandas/%EA%B3%B5%EA%B3%B5%EB%8D%B0%EC%9D%B4%ED%84%B0-%ED%95%9C%EA%B8%80%EA%B9%A8%EC%A7%90%ED%98%84%EC%83%81-%ED%95%B4%EA%B2%B0%EB%B0%A9%EB%B2%95

data = pd.read_csv('Apartment.csv',thousands = ',')

# %%
data.head()
# Out:
#            시군구   번지   본번  부번           단지명    전용면적    계약년월  계약일   거래금액   층  \
# 0  강원도 강릉시 견소동  202  202   0          송정한신  43.380  202004    4  10000   9
# 1  강원도 강릉시 견소동  202  202   0          송정한신  84.930  202004    7  17300   8
# 2  강원도 강릉시 견소동  202  202   0          송정한신  84.945  202004   10  14000   6
# 3  강원도 강릉시 견소동  289  289   0  송정해변신도브래뉴아파트  59.990  202004    7  13650   1
# 4  강원도 강릉시 견소동  289  289   0  송정해변신도브래뉴아파트  84.990  202004   11  23700  12
#
#    건축년도           도로명
# 0  1997   경강로2539번길 8
# 1  1997   경강로2539번길 8
# 2  1997   경강로2539번길 8
# 3  2005  경강로2539번길 22
# 4  2005  경강로2539번길 22

# %%
addr = data['시군구'].str.split(' ')

#addr = addr[:][0] + addr[:][1]
for i in range(addr.size):
    addr[i] = addr[i][0] + addr[i][1]

# %%
data['지역'] = addr
data.drop('시군구', axis=1, inplace=True)

# %%
data.head()
# Out:
#     번지   본번  부번           단지명    전용면적    계약년월  계약일   거래금액   층  건축년도  \
# 0  202  202   0          송정한신  43.380  202004    4  10000   9  1997
# 1  202  202   0          송정한신  84.930  202004    7  17300   8  1997
# 2  202  202   0          송정한신  84.945  202004   10  14000   6  1997
# 3  289  289   0  송정해변신도브래뉴아파트  59.990  202004    7  13650   1  2005
# 4  289  289   0  송정해변신도브래뉴아파트  84.990  202004   11  23700  12  2005
#
#             도로명      지역
# 0   경강로2539번길 8  강원도강릉시
# 1   경강로2539번길 8  강원도강릉시
# 2   경강로2539번길 8  강원도강릉시
# 3  경강로2539번길 22  강원도강릉시
# 4  경강로2539번길 22  강원도강릉시

# %%
data['지역'].unique().size
# Out:
# 266

# %%
data['지역'].value_counts()
# Out:
# 경기도남양주시       922
# 경기도화성시        806
# 인천광역시남동구      744
# 대구광역시달서구      730
# 경기도시흥시        723
# 경기도부천시        705
# 인천광역시연수구      668
# 경기도평택시        651
# 인천광역시부평구      638
# 인천광역시서구       575
# 경기도의정부시       557
# 경기도김포시        552
# 충청남도천안서북구     523
# 강원도원주시        510
# 충청북도청주흥덕구     504
# 경상남도김해시       482
# 경기도용인기흥구      480
# 광주광역시북구       474
# 경기도안산단원구      472
# 대전광역시서구       462
# 경상북도구미시       453
# 경기도고양덕양구      448
# 충청남도아산시       418
# 충청남도천안동남구     415
# 경상남도양산시       406
# 전라북도전주완산구     404
# 대구광역시북구       403
# 경기도고양일산서구     393
# 광주광역시광산구      392
# 인천광역시미추홀구     391
#              ...
# 전라북도진안군         6
# 전라남도진도군         6
# 전라남도장흥군         6
# 경상북도영덕군         5
# 세종특별자치시연동면      5
# 인천광역시강화군        5
# 경상남도남해군         5
# 강원도양구군          5
# 전라북도임실군         5
# 경상남도의령군         5
# 경상북도영양군         4
# 전라북도장수군         4
# 세종특별자치시반곡동      4
# 경상북도성주군         4
# 전라남도담양군         4
# 강원도영월군          4
# 경상북도봉화군         4
# 전라남도곡성군         4
# 세종특별자치시어진동      4
# 세종특별자치시연서면      3
# 경상북도청송군         3
# 경상남도산청군         3
# 전라남도구례군         2
# 강원도화천군          2
# 전라북도순창군         2
# 전라북도무주군         2
# 세종특별자치시소정면      1
# 전라남도함평군         1
# 세종특별자치시전의면      1
# 경상북도울릉군         1
# Name: 지역, Length: 266, dtype: int64

# %%
data['면적금액'] = data['거래금액'] / data['전용면적']

# %%
data.head()
# Out:
#     번지   본번  부번           단지명    전용면적    계약년월  계약일   거래금액   층  건축년도  \
# 0  202  202   0          송정한신  43.380  202004    4  10000   9  1997
# 1  202  202   0          송정한신  84.930  202004    7  17300   8  1997
# 2  202  202   0          송정한신  84.945  202004   10  14000   6  1997
# 3  289  289   0  송정해변신도브래뉴아파트  59.990  202004    7  13650   1  2005
# 4  289  289   0  송정해변신도브래뉴아파트  84.990  202004   11  23700  12  2005
#
#             도로명      지역        면적금액
# 0   경강로2539번길 8  강원도강릉시  230.520977
# 1   경강로2539번길 8  강원도강릉시  203.697162
# 2   경강로2539번길 8  강원도강릉시  164.812526
# 3  경강로2539번길 22  강원도강릉시  227.537923
# 4  경강로2539번길 22  강원도강릉시  278.856336

# %%
data[['지역','면적금액','거래금액']].groupby(['지역']).mean().astype(int).sort_values(by='면적금액')
# Out:
#             면적금액    거래금액
# 지역
# 전라남도영암군       56    2804
# 전라남도고흥군       83    4406
# 세종특별자치시소정면    84    5000
# 강원도영월군        89    3792
# 전라북도진안군       95    5516
# 충청북도단양군      115    5273
# 세종특별자치시전의면   115    5800
# 경상북도청도군      116    7887
# 강원도정선군       117    6364
# 충청남도태안군      120    8219
# 전라남도진도군      128    8875
# 세종특별자치시부강면   128    6758
# 전라북도임실군      130    8020
# 전라남도곡성군      133    7850
# 경상북도영양군      134   10250
# 전라남도보성군      134    8122
# 경상북도칠곡군      136    9655
# 경상북도영천시      137    9402
# 충청북도증평군      138   10319
# 경상북도영덕군      140    9660
# 경상남도합천군      140    9835
# 경상북도청송군      140   11020
# 경상남도하동군      141   10262
# 세종특별자치시연동면   142    7540
# 경상북도영주시      143   10032
# 전라남도장성군      144    8736
# 경상남도남해군      145   10020
# 강원도태백시       146    8545
# 강원도동해시       148   10528
# 충청북도제천시      150   10359
# ...          ...     ...
# 세종특별자치시소담동   696   53429
# 서울특별시중랑구     700   44481
# 서울특별시구로구     708   45528
# 서울특별시은평구     711   47318
# 서울특별시노원구     734   44491
# 경기도광명시       742   48543
# 세종특별자치시보람동   744   55178
# 서울특별시관악구     771   55219
# 경기도하남시       782   59025
# 서울특별시서대문구    793   63370
# 서울특별시강서구     804   53095
# 세종특별자치시새롬동   806   63086
# 서울특별시성북구     814   59660
# 세종특별자치시대평동   837   61966
# 서울특별시종로구     876   68208
# 서울특별시동대문구    925   59448
# 서울특별시강동구     965   62250
# 서울특별시동작구     990   81732
# 서울특별시양천구     993   77100
# 서울특별시중구     1058   82153
# 서울특별시영등포구   1070   72432
# 경기도성남분당구    1119   81860
# 서울특별시광진구    1165   83225
# 서울특별시마포구    1172   79249
# 서울특별시성동구    1339  105930
# 서울특별시용산구    1354  126683
# 경기도과천시      1487  134625
# 서울특별시송파구    1585  119590
# 서울특별시서초구    1821  173201
# 서울특별시강남구    2043  197279
#
# [266 rows x 2 columns]

# %%
data.isnull().sum()
# Out:
# 번지      5
# 본번      0
# 부번      0
# 단지명     0
# 전용면적    0
# 계약년월    0
# 계약일     0
# 거래금액    0
# 층       0
# 건축년도    0
# 도로명     0
# 지역      0
# 면적금액    0
# dtype: int64

# %%
#heatmap_data = data[['전용면적', '거래금액', '층', '건축년도', '지역', '면적금액']] 

#colormap = plt.cm.RdBu
#plt.figure(figsize=(14, 12))
#plt.title('Pearson Correlation of Features', y=1.05, size=15)
#sns.heatmap(heatmap_data.astype(float).corr(), linewidths=0.1, vmax=1.0,
#           square=True, cmap=colormap, linecolor='white', annot=True, annot_kws={"size": 16})
#
#del heatmap_data

# %%
data['전용면적'] = data['전용면적'].round().astype(int)

# %%
data['전용면적'].head()
# Out:
# 0    43
# 1    85
# 2    85
# 3    60
# 4    85
# Name: 전용면적, dtype: int64

# %%
data[['건축년도','전용면적','거래금액']].groupby(['건축년도','전용면적']).mean().head()
# Out:
#                    거래금액
# 건축년도 전용면적
# 1961 56    17450.000000
# 1962 36     2475.000000
#      50     5300.000000
# 1966 29    36500.000000
# 1969 36    11583.333333

# %%
fig, ax = plt.subplots(1,1, figsize=(10,5))

groups = data[['건축년도','면적금액']].groupby('건축년도').mean()



for p in groups:
    
    ax.plot(data.건축년도.astype(int), 

            p, 

            marker='o', 

            linestyle='')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-64e7e8be7232> in <module>
#      13             marker='o',
#      14
# ---> 15             linestyle='')
#      16
#      17 plt.show()
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, *args, **kwargs)
#    1609         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
#    1610
# -> 1611         for line in self._get_lines(*args, **kwargs):
#    1612             self.add_line(line)
#    1613             lines.append(line)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/axes/_base.py in _grab_next_args(self, *args, **kwargs)
#     391                 this += args[0],
#     392                 args = args[1:]
# --> 393             yield from self._plot_args(this, kwargs)
#     394
#     395
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     340         ret = []
#     341         if len(tup) > 1 and isinstance(tup[-1], str):
# --> 342             linestyle, marker, color = _process_plot_format(tup[-1])
#     343             tup = tup[:-1]
#     344         elif len(tup) == 3:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/axes/_base.py in _process_plot_format(fmt)
#     116         else:
#     117             raise ValueError(
# --> 118                 'Unrecognized character %c in format string' % c)
#     119         i += 1
#     120
#
# ValueError: Unrecognized character 면 in format string
