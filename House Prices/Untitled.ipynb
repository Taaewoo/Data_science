# %%
import sys

# %matplotlib inline
import d2l
from mxnet import autograd, gluon, init, nd
from mxnet.gluon import data as gdata, loss as gloss, nn
import numpy as np
import pandas as pd

# %%
train_data = pd.read_csv("./csv/train.csv")
test_data = pd.read_csv("./csv/test.csv")

# %%
print(train_data.shape)
print(test_data.shape)
# Out:
# (1460, 81)
# (1459, 80)

# %%
train_data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0      2   2008        WD         Normal     208500
# 1      5   2007        WD         Normal     181500
# 2      9   2008        WD         Normal     223500
# 3      2   2006        WD        Abnorml     140000
# 4     12   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
train_data.drop(['Id'],axis=1,inplace=True)

# %%
train_data.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL         65.0     8450   Pave   NaN      Reg
# 1          20       RL         80.0     9600   Pave   NaN      Reg
# 2          60       RL         68.0    11250   Pave   NaN      IR1
# 3          70       RL         60.0     9550   Pave   NaN      IR1
# 4          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig    ...     PoolArea PoolQC Fence  \
# 0         Lvl    AllPub    Inside    ...            0    NaN   NaN
# 1         Lvl    AllPub       FR2    ...            0    NaN   NaN
# 2         Lvl    AllPub    Inside    ...            0    NaN   NaN
# 3         Lvl    AllPub    Corner    ...            0    NaN   NaN
# 4         Lvl    AllPub       FR2    ...            0    NaN   NaN
#
#   MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# 0         NaN       0      2    2008        WD         Normal     208500
# 1         NaN       0      5    2007        WD         Normal     181500
# 2         NaN       0      9    2008        WD         Normal     223500
# 3         NaN       0      2    2006        WD        Abnorml     140000
# 4         NaN       0     12    2008        WD         Normal     250000
#
# [5 rows x 80 columns]

# %%
test_data.drop(['Id'],axis=1,inplace=True)

# %%
all_features = pd.concat((train_data.iloc[:, 1:-1], test_data.iloc[:, 1:]))
all_features.shape
# Out:
# (2919, 78)

# %%
all_features.dtypes.head()
# Out:
# MSZoning        object
# LotFrontage    float64
# LotArea        float64
# Street          object
# Alley           object
# dtype: object

# %%
# 데이터 전처리로 숫자형 데이터를 모두 데이터 표준화를 진행함.
# 평균은 0, 분산은 1로 조정.

numeric_features = all_features.dtypes[all_features.dtypes != 'object'].index
all_features[numeric_features] = all_features[numeric_features].apply(
    lambda x: (x - x.mean()) / (x.std()))
# After standardizing the data all means vanish, hence we can set missing
# values to 0
all_features = all_features.fillna(0)

# %%
all_features[numeric_features].head()
# Out:
#    LotFrontage   LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 0    -0.184443 -0.217841     0.646073    -0.507197   1.046078      0.896679
# 1     0.458096 -0.072032    -0.063174     2.187904   0.154737     -0.395536
# 2    -0.055935  0.137173     0.646073    -0.507197   0.980053      0.848819
# 3    -0.398622 -0.078371     0.646073    -0.507197  -1.859033     -0.682695
# 4     0.629439  0.518814     1.355319    -0.507197   0.947040      0.753100
#
#    MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF    ...     GarageArea  \
# 0    0.523038    0.580708    -0.29303  -0.934542    ...       0.348780
# 1   -0.569893    1.177709    -0.29303  -0.629681    ...      -0.059772
# 2    0.333448    0.097840    -0.29303  -0.288418    ...       0.627338
# 3   -0.569893   -0.494771    -0.29303  -0.047258    ...       0.785188
# 4    1.381770    0.468770    -0.29303  -0.161013    ...       1.685860
#
#    WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  \
# 0   -0.740634     0.199972      -0.359539  -0.103313    -0.285886 -0.063139
# 1    1.614603    -0.702722      -0.359539  -0.103313    -0.285886 -0.063139
# 2   -0.740634    -0.081195      -0.359539  -0.103313    -0.285886 -0.063139
# 3   -0.740634    -0.184783       3.874303  -0.103313    -0.285886 -0.063139
# 4    0.776834     0.540332      -0.359539  -0.103313    -0.285886 -0.063139
#
#     MiscVal    MoSold    YrSold
# 0 -0.089577 -1.551918  0.157619
# 1 -0.089577 -0.446848 -0.602858
# 2 -0.089577  1.026577  0.157619
# 3 -0.089577 -1.551918 -1.363335
# 4 -0.089577  2.131647  0.157619
#
# [5 rows x 35 columns]

# %%
# Dummy_na=True refers to a missing value being a legal eigenvalue, and
# creates an indicative feature for it
all_features = pd.get_dummies(all_features, dummy_na=True)
all_features.shape
# Out:
# (2919, 353)

# %%
n_train = train_data.shape[0]
train_features = nd.array(all_features[:n_train].values)
test_features = nd.array(all_features[n_train:].values)
train_labels = nd.array(train_data.SalePrice.values).reshape((-1, 1))
